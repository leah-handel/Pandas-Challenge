# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
school_data_complete.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# School ID        39170
# type             39170
# size             39170
# budget           39170
# dtype: int64

# %%
#calculating totals

totalschools = school_data["school_name"].count()
totalstudents = len(school_data_complete["Student ID"].unique())

totalbudget = school_data["budget"].sum()

print(totalstudents)

#compared the above to the count of rows in school_data_complete to confirm there weren't any students with multiple records
# Out:
# 39170

# %%
readingavg = school_data_complete["reading_score"].mean()
mathavg = school_data_complete["math_score"].mean()
print(mathavg)
# Out:
# 78.98537145774827

# %%
passedreading = school_data_complete.loc[school_data_complete["reading_score"] >= 70,:]
totalpassedreading = passedreading["Student ID"].count()
readingpasspct = totalpassedreading/totalstudents*100
print(readingpasspct)
# Out:
# 85.80546336482001

# %%
passedmath = school_data_complete.loc[school_data_complete["math_score"] >= 70,:]
totalpassedmath = passedmath["Student ID"].count()
mathpasspct = totalpassedmath/totalstudents*100
print(mathpasspct)
# Out:
# 74.9808526933878

# %%
passedboth = school_data_complete.loc[(school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70),:]
totalpassedboth = passedboth["Student ID"].count()
bothpasspct = totalpassedboth/totalstudents*100
print(bothpasspct)
# Out:
# 65.17232575950983

# %%
District_Summary = pd.DataFrame({"Number of Schools":[totalschools], 
                                "Number of Students":[totalstudents], 
                                "Total Budget": [totalbudget],
                                "Average Math Score": [mathavg],
                                "Average Reading Score": [readingavg],
                                "Percent Passing Math": [mathpasspct],
                                "Percent Passing Reading": [readingpasspct],
                                "Percent Passing Overall": [bothpasspct]})
District_Summary
# Out:
#    Number of Schools  Number of Students  Total Budget  Average Math Score  \
# 0                 15               39170      24649428           78.985371
#
#    Average Reading Score  Percent Passing Math  Percent Passing Reading  \
# 0               81.87784             74.980853                85.805463
#
#                              Percent Passing Overall
# 0  Budget Range (Dollars Per Student)
# 575 - 599  ...

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
grouped = school_data_complete.groupby(['school_name'])
grouped.count()
# Out:
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4976          4976    4976   4976           4976
# Cabrera High School          1858          1858    1858   1858           1858
# Figueroa High School         2949          2949    2949   2949           2949
# Ford High School             2739          2739    2739   2739           2739
# Griffin High School          1468          1468    1468   1468           1468
# Hernandez High School        4635          4635    4635   4635           4635
# Holden High School            427           427     427    427            427
# Huang High School            2917          2917    2917   2917           2917
# Johnson High School          4761          4761    4761   4761           4761
# Pena High School              962           962     962    962            962
# Rodriguez High School        3999          3999    3999   3999           3999
# ...

# %%
alpha_school_data = school_data.sort_values(by="school_name", ascending="false")

# %%
schoolnames = alpha_school_data["school_name"]
alpha_school_data = alpha_school_data.set_index(schoolnames)
alpha_school_data = alpha_school_data[['type', 'size', 'budget']]

alpha_school_data

#getting this into a nice format and indexed by school name so that data pulled from it can merge with the data pulled from the grouped dataframe
# Out:
#                            type  size   budget
# school_name
# Bailey High School     District  4976  3124928
# Cabrera High School     Charter  1858  1081356
# Figueroa High School   District  2949  1884411
# Ford High School       District  2739  1763916
# Griffin High School     Charter  1468   917500
# Hernandez High School  District  4635  3022020
# Holden High School      Charter   427   248087
# Huang High School      District  2917  1910635
# Johnson High School    District  4761  3094650
# Pena High School        Charter   962   585858
# Rodriguez High School  District  3999  2547363
# Shelton High School     Charter  1761  1056600
# Thomas High School      Charter  1635  1043130
# Wilson High School      Charter  2283  1319574
# Wright High School      Charter  1800  1049400

# %%
schooltypes = alpha_school_data["type"]
budget_school=alpha_school_data["budget"]
totalstudents_school=alpha_school_data["size"]

# %%
#totalstudents_school = grouped["Student ID"].count()

# %%
budgetperstudent=budget_school/totalstudents_school

# %%
mathavg_school = grouped["math_score"].mean()
readingavg_school = grouped["reading_score"].mean()

# %%
passedreading_school = passedreading.groupby(["school_name"])
totalpassedreading_school = passedreading_school["Student ID"].count()
readingpasspct_school = totalpassedreading_school/totalstudents_school*100

# %%
passedmath_school = passedmath.groupby(["school_name"])
totalpassedmath_school = passedmath_school["Student ID"].count()
mathpasspct_school = totalpassedmath_school/totalstudents_school*100

# %%
passedboth_school = passedboth.groupby(["school_name"])
totalpassedboth_school = passedboth_school["Student ID"].count()
bothpasspct_school = totalpassedboth_school/totalstudents_school*100

# %%
school_summary = pd.DataFrame({"School Type":schooltypes,
                                "Number of Students": totalstudents_school,
                                "Budget": budget_school,
                               "Budget per Student": budgetperstudent,
                                "Average Math Score": mathavg_school,
                                "Average Reading Score": readingavg_school,
                                "Percent Passing Math": mathpasspct_school,
                                "Percent Passing Reading": readingpasspct_school,
                                "Percent Passing Overall": bothpasspct_school})

school_summary
# Out:
#                       School Type  Number of Students   Budget  \
# school_name
# Bailey High School       District                4976  3124928
# Cabrera High School       Charter                1858  1081356
# Figueroa High School     District                2949  1884411
# Ford High School         District                2739  1763916
# Griffin High School       Charter                1468   917500
# Hernandez High School    District                4635  3022020
# Holden High School        Charter                 427   248087
# Huang High School        District                2917  1910635
# Johnson High School      District                4761  3094650
# Pena High School          Charter                 962   585858
# Rodriguez High School    District                3999  2547363
# Shelton High School       Charter                1761  1056600
# Thomas High School        Charter                1635  1043130
# Wilson High School        Charter                2283  1319574
# ...

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_schools = school_summary.sort_values(by="Percent Passing Overall", ascending=False)

top_schools.head(5)
# Out:
#                     School Type  Number of Students   Budget  \
# school_name
# Cabrera High School     Charter                1858  1081356
# Thomas High School      Charter                1635  1043130
# Griffin High School     Charter                1468   917500
# Wilson High School      Charter                2283  1319574
# Pena High School        Charter                 962   585858
#
#                      Budget per Student  Average Math Score  \
# school_name
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  Percent Passing Math  \
# school_name
# Cabrera High School              83.975780             94.133477
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_schools = school_summary.sort_values(by="Percent Passing Overall", ascending=True)

bottom_schools.head(5)
# Out:
#                       School Type  Number of Students   Budget  \
# school_name
# Rodriguez High School    District                3999  2547363
# Figueroa High School     District                2949  1884411
# Huang High School        District                2917  1910635
# Hernandez High School    District                4635  3022020
# Johnson High School      District                4761  3094650
#
#                        Budget per Student  Average Math Score  \
# school_name
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  Percent Passing Math  \
# school_name
# Rodriguez High School              80.744686             66.366592
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.dtypes
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# School ID         int64
# type             object
# size              int64
# budget            int64
# dtype: object

# %%
grade9 = school_data_complete.loc[school_data_complete["grade"] == "9th",:]
grade10 = school_data_complete.loc[school_data_complete["grade"] == "10th",:]
grade11 = school_data_complete.loc[school_data_complete["grade"] == "11th",:]
grade12 = school_data_complete.loc[school_data_complete["grade"] == "12th",:]

# %%
grouped9 = grade9.groupby(['school_name'])
grouped10 = grade10.groupby(['school_name'])
grouped11 = grade11.groupby(['school_name'])
grouped12 = grade12.groupby(['school_name'])

# %%
mathavg9 = grouped9["math_score"].mean()
mathavg10 = grouped10["math_score"].mean()
mathavg11 = grouped11["math_score"].mean()
mathavg12 = grouped12["math_score"].mean()

# %%
mathavg_grade = pd.DataFrame({"Average 9th Grade Math Score":mathavg9,
                                "Average 10th Grade Math Score":mathavg10,
                                "Average 11th Grade Math Score":mathavg11,
                                "Average 12th Grade Math Score":mathavg12})
mathavg_grade
# Out:
#                        Average 9th Grade Math Score  \
# school_name
# Bailey High School                        77.083676
# Cabrera High School                       83.094697
# Figueroa High School                      76.403037
# Ford High School                          77.361345
# Griffin High School                       82.044010
# Hernandez High School                     77.438495
# Holden High School                        83.787402
# Huang High School                         77.027251
# Johnson High School                       77.187857
# Pena High School                          83.625455
# Rodriguez High School                     76.859966
# Shelton High School                       83.420755
# Thomas High School                        83.590022
# Wilson High School                        83.085578
# Wright High School                        83.264706
#
#                        Average 10th Grade Math Score  \
# school_name
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
readingavg9 = grouped9['reading_score'].mean()
readingavg10 = grouped10['reading_score'].mean()
readingavg11 = grouped11['reading_score'].mean()
readingavg12 = grouped12['reading_score'].mean()

# %%
readingavg_grade = pd.DataFrame({"Average 9th Grade Reading Score":readingavg9,
                                "Average 10th Grade Reading Score":readingavg10,
                                "Average 11th Grade Reading Score":readingavg11,
                                "Average 12th Grade Reading Score":readingavg12})
readingavg_grade
# Out:
#                        Average 9th Grade Reading Score  \
# school_name
# Bailey High School                           81.303155
# Cabrera High School                          83.676136
# Figueroa High School                         81.198598
# Ford High School                             80.632653
# Griffin High School                          83.369193
# Hernandez High School                        80.866860
# Holden High School                           83.677165
# Huang High School                            81.290284
# Johnson High School                          81.260714
# Pena High School                             83.807273
# Rodriguez High School                        80.993127
# Shelton High School                          84.122642
# Thomas High School                           83.728850
# Wilson High School                           83.939778
# Wright High School                           83.833333
#
#                        Average 10th Grade Reading Score  \
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
school_aspects = school_data_complete 
#making a new dataframe so i don't mess up the one that's working!

#looking at these binning problems as being essentially the same as the summary by school
#school was just a bin that the data had come pre-assigned to the data
#once we bin by budget, type, and size we can treat these the same way

# %%
school_aspects["Budget per Student"] = school_aspects["budget"]/school_aspects["size"]
school_aspects
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
school_summary["Budget per Student"].sort_values()
#pulled from school summary so it wouldn't have all the repeated values for each school
# Out:
# school_name
# Wilson High School       578.0
# Holden High School       581.0
# Cabrera High School      582.0
# Wright High School       583.0
# Shelton High School      600.0
# Pena High School         609.0
# Griffin High School      625.0
# Bailey High School       628.0
# Rodriguez High School    637.0
# Thomas High School       638.0
# Figueroa High School     639.0
# Ford High School         644.0
# Johnson High School      650.0
# Hernandez High School    652.0
# Huang High School        655.0
# Name: Budget per Student, dtype: float64

# %%
bins = [575,600,625,650,675]
groupnames = ["575 - 599","600 - 624","625 - 649","650 - 675"]

# %%
school_aspects["Budget Range (Dollars Per Student)"] = pd.cut(school_aspects["Budget per Student"], bins, labels = groupnames)

# %%
school_aspects
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
#These are the bins for School Size in the following activity!! I'm putting them in up here so that when I create the updated dataframes 
#of students who passed reading, math, and both, the bins will be in there and I can reuse for the size analysis
#no need to add bins for type because type functions like a bin, the same way school did.

school_summary["Number of Students"].sort_values()
# Out:
# school_name
# Holden High School        427
# Pena High School          962
# Griffin High School      1468
# Thomas High School       1635
# Shelton High School      1761
# Wright High School       1800
# Cabrera High School      1858
# Wilson High School       2283
# Ford High School         2739
# Huang High School        2917
# Figueroa High School     2949
# Rodriguez High School    3999
# Hernandez High School    4635
# Johnson High School      4761
# Bailey High School       4976
# Name: Number of Students, dtype: int64

# %%
bins = [0,1000,2000,3500,5000]
groupnames = ["Fewer than 1,000","1,000 to 1,999","2,000 to 3,499","3,500+"]

# %%
school_aspects["Size Range (Number of Students)"] = pd.cut(school_aspects["size"], bins, labels = groupnames)
school_aspects
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
#now that school_aspects has all the bins in it, on with pulling data by budget
grouped_by_budget = school_aspects.groupby("Budget Range (Dollars Per Student)")

# %%
grouped_by_budget.mean()
# Out:
#                                       Student ID  reading_score  math_score  \
# Budget Range (Dollars Per Student)
# 575 - 599                           16287.123385      83.912412   83.362283
# 600 - 624                           17254.824280      83.906996   83.544856
# 625 - 649                           25758.781993      81.162258   77.469253
# 650 - 675                            6666.237553      81.030323   77.034693
#
#                                     School ID         size        budget  \
# Budget Range (Dollars Per Student)
# 575 - 599                            5.843400  1868.335958  1.092050e+06
# 600 - 624                            5.979424  1267.682305  7.862080e+05
# 625 - 649                            9.373617  3907.671067  2.496044e+06
# 650 - 675                            1.841234  3971.413400  2.592742e+06
#
#                                     Budget Per Student  Budget per Student
# Budget Range (Dollars Per Student)
# ...

# %%
mathavg_spending = grouped_by_budget.mean()["math_score"]
readingavg_spending = grouped_by_budget.mean()["reading_score"]

# %%
passedreading_update = school_aspects.loc[school_aspects["reading_score"] >= 70,:]
passedreading_update
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# 1                 94          61          0  District  2917  1910635
# ...

# %%
passedreading_budget = passedreading_update.groupby("Budget Range (Dollars Per Student)")

# %%
totalpassedreading_budget = passedreading_budget["Student ID"].count()
totalstudents_budget = grouped_by_budget["Student ID"].count()

# %%
readingpasspct_budget = totalpassedreading_budget/totalstudents_budget*100
readingpasspct_budget
# Out:
# Budget Range (Dollars Per Student)
# 575 - 599    96.506335
# 600 - 624    96.666667
# 625 - 649    82.131155
# 650 - 675    81.038136
# Name: Student ID, dtype: float64

# %%
#have to update my dataframes of just students who passed math, reading, and both because the original version I made for the school summary table didn't have these later bins in it. I could go back and put the bins in that df instead of my new one but I'm nervous about messing up the data for other cells by accident!
passedmath_update = school_aspects.loc[school_aspects["math_score"] >= 70,:]
passedmath_budget = passedmath_update.groupby("Budget Range (Dollars Per Student)")

# %%
totalpassedmath_budget = passedmath_budget["Student ID"].count()

# %%
mathpasspct_budget = totalpassedmath_budget/totalstudents_budget*100
mathpasspct_budget
# Out:
# Budget Range (Dollars Per Student)
# 575 - 599    93.738467
# 600 - 624    93.868313
# 625 - 649    68.659481
# 650 - 675    66.340042
# Name: Student ID, dtype: float64

# %%
passedboth_update = school_aspects.loc[(school_aspects["math_score"] >= 70) & (school_aspects["reading_score"] >= 70),:]
passedboth_budget = passedboth_update.groupby(["Budget Range (Dollars Per Student)"])

# %%
totalpassedboth_budget = passedboth_budget["Student ID"].count()

# %%
bothpasspct_budget = totalpassedboth_budget/totalstudents_budget*100
bothpasspct_budget
# Out:
# Budget Range (Dollars Per Student)
# 575 - 599    90.478534
# 600 - 624    90.576132
# 625 - 649    56.650363
# 650 - 675    53.522246
# Name: Student ID, dtype: float64

# %%
Budget_Summary = pd.DataFrame({
                                "Average Math Score": mathavg_spending,
                                "Average Reading Score": readingavg_spending,
                                "Percent Passing Math": mathpasspct_budget,
                                "Percent Passing Reading": readingpasspct_budget,
                                "Percent Passing Overall": bothpasspct_budget})

Budget_Summary
# Out:
#                                     Average Math Score  Average Reading Score  \
# Budget Range (Dollars Per Student)
# 575 - 599                                    83.362283              83.912412
# 600 - 624                                    83.544856              83.906996
# 625 - 649                                    77.469253              81.162258
# 650 - 675                                    77.034693              81.030323
#
#                                     Percent Passing Math  \
# Budget Range (Dollars Per Student)
# 575 - 599                                      93.738467
# 600 - 624                                      93.868313
# 625 - 649                                      68.659481
# 650 - 675                                      66.340042
#
#                                     Percent Passing Reading  \
# Budget Range (Dollars Per Student)
# 575 - 599                                         96.506335
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
#added bins for school size to the school_aspects dataframe in the exercise above

# %%
grouped_by_size = school_aspects.groupby("Size Range (Number of Students)")
grouped_by_size.mean()
# Out:
#                                    Student ID  reading_score  math_score  \
# Size Range (Number of Students)
# Fewer than 1,000                 23541.000000      83.974082   83.828654
# 1,000 to 1,999                   19993.408472      83.867989   83.372682
# 2,000 to 3,499                   13795.781870      81.654758   78.164034
# 3,500+                           22526.488270      80.928365   77.070764
#
#                                  School ID         size        budget  \
# Size Range (Number of Students)
# Fewer than 1,000                  8.692585   797.532757  4.820220e+05
# 1,000 to 1,999                    7.208636  1715.739732  1.033931e+06
# 2,000 to 3,499                    4.589548  2747.951874  1.742690e+06
# 3,500+                            8.157313  4621.573295  2.965393e+06
#
#                                  Budget Per Student  Budget per Student
# Size Range (Number of Students)
# Fewer than 1,000                         600.392369          600.392369
# ...

# %%
#average scores and pass percentages are the same process as above
mathavg_size = grouped_by_size.mean()["math_score"]
readingavg_size = grouped_by_size.mean()["reading_score"]

# %%
passedreading_size = passedreading_update.groupby("Size Range (Number of Students)")

# %%
totalpassedreading_size = passedreading_size["Student ID"].count()
totalstudents_size = grouped_by_size["Student ID"].count()

# %%
readingpasspct_size = totalpassedreading_size/totalstudents_size*100
readingpasspct_size
# Out:
# Size Range (Number of Students)
# Fewer than 1,000    96.040317
# 1,000 to 1,999      96.773058
# 2,000 to 3,499      83.844600
# 3,500+              81.106091
# Name: Student ID, dtype: float64

# %%
passedmath_size = passedmath_update.groupby("Size Range (Number of Students)")

# %%
totalpassedmath_size = passedmath_size["Student ID"].count()
mathpasspct_size = totalpassedmath_size/totalstudents_size*100
mathpasspct_size
# Out:
# Size Range (Number of Students)
# Fewer than 1,000    93.952484
# 1,000 to 1,999      93.616522
# 2,000 to 3,499      72.336517
# 3,500+              66.468891
# Name: Student ID, dtype: float64

# %%
passedboth_size = passedboth_update.groupby("Size Range (Number of Students)")

# %%
totalpassedboth_size = passedboth_size["Student ID"].count()
bothpasspct_size = totalpassedboth_size/totalstudents_size*100
bothpasspct_size
# Out:
# Size Range (Number of Students)
# Fewer than 1,000    90.136789
# 1,000 to 1,999      90.624267
# 2,000 to 3,499      61.397869
# 3,500+              53.715094
# Name: Student ID, dtype: float64

# %%
Size_Summary = pd.DataFrame({
                                "Average Math Score": mathavg_size,
                                "Average Reading Score": readingavg_size,
                                "Percent Passing Math": mathpasspct_size,
                                "Percent Passing Reading": readingpasspct_size,
                                "Percent Passing Overall": bothpasspct_size})

Size_Summary
# Out:
#                                  Average Math Score  Average Reading Score  \
# Size Range (Number of Students)
# Fewer than 1,000                          83.828654              83.974082
# 1,000 to 1,999                            83.372682              83.867989
# 2,000 to 3,499                            78.164034              81.654758
# 3,500+                                    77.070764              80.928365
#
#                                  Percent Passing Math  \
# Size Range (Number of Students)
# Fewer than 1,000                            93.952484
# 1,000 to 1,999                              93.616522
# 2,000 to 3,499                              72.336517
# 3,500+                                      66.468891
#
#                                  Percent Passing Reading  \
# Size Range (Number of Students)
# Fewer than 1,000                               96.040317
# 1,000 to 1,999                                 96.773058
# ...

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
