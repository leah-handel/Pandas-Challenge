# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
school_data_complete.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# School ID        39170
# type             39170
# size             39170
# budget           39170
# dtype: int64

# %%
#calculating totals

totalschools = school_data["school_name"].count()
totalstudents = len(school_data_complete["Student ID"].unique())

totalbudget = school_data["budget"].sum()

print(totalstudents)

#compared the above to the count of rows in school_data_complete to confirm there weren't any students with multiple records
# Out:
# 39170

# %%
readingavg = school_data_complete["reading_score"].mean()
mathavg = school_data_complete["math_score"].mean()
print(mathavg)
# Out:
# 78.98537145774827

# %%
passedreading = school_data_complete.loc[school_data_complete["reading_score"] >= 70,:]
totalpassedreading = passedreading["Student ID"].count()
readingpasspct = totalpassedreading/totalstudents*100
print(readingpasspct)
# Out:
# 85.80546336482001

# %%
passedmath = school_data_complete.loc[school_data_complete["math_score"] >= 70,:]
totalpassedmath = passedmath["Student ID"].count()
mathpasspct = totalpassedmath/totalstudents*100
print(mathpasspct)
# Out:
# 74.9808526933878

# %%
passedboth = school_data_complete.loc[(school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70),:]
totalpassedboth = passedboth["Student ID"].count()
bothpasspct = totalpassedboth/totalstudents*100
print(bothpasspct)
# Out:
# 65.17232575950983

# %%
District_Summary = pd.DataFrame({"Number of Schools":[totalschools], 
                                "Number of Students":[totalstudents], 
                                "Total Budget": [totalbudget],
                                "Average Math Score": [mathavg],
                                "Average Reading Score": [readingavg],
                                "Percent Passing Math": [mathpasspct],
                                "Percent Passing Reading": [mathpasspct],
                                "Percent Passing Overall": [bothpasspct]})
District_Summary
# Out:
#    Number of Schools  Number of Students  Total Budget  Average Math Score  \
# 0                 15               39170      24649428           78.985371
#
#    Average Reading Score  Percent Passing Math  Percent Passing Reading  \
# 0               81.87784             74.980853                74.980853
#
#    Percent Passing Overall
# 0                65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
grouped = school_data_complete.groupby(['school_name'])
grouped.count()
# Out:
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4976          4976    4976   4976           4976
# Cabrera High School          1858          1858    1858   1858           1858
# Figueroa High School         2949          2949    2949   2949           2949
# Ford High School             2739          2739    2739   2739           2739
# Griffin High School          1468          1468    1468   1468           1468
# Hernandez High School        4635          4635    4635   4635           4635
# Holden High School            427           427     427    427            427
# Huang High School            2917          2917    2917   2917           2917
# Johnson High School          4761          4761    4761   4761           4761
# Pena High School              962           962     962    962            962
# Rodriguez High School        3999          3999    3999   3999           3999
# Shelton High School          1761          1761    1761   1761           1761
# Thomas High School           1635          1635    1635   1635           1635
# Wilson High School           2283          2283    2283   2283           2283
# Wright High School           1800          1800    1800   1800           1800
#
#                        math_score  School ID  type  size  budget
# school_name
# Bailey High School           4976       4976  4976  4976    4976
# Cabrera High School          1858       1858  1858  1858    1858
# Figueroa High School         2949       2949  2949  2949    2949
# Ford High School             2739       2739  2739  2739    2739
# Griffin High School          1468       1468  1468  1468    1468
# Hernandez High School        4635       4635  4635  4635    4635
# Holden High School            427        427   427   427     427
# Huang High School            2917       2917  2917  2917    2917
# Johnson High School          4761       4761  4761  4761    4761
# Pena High School              962        962   962   962     962
# Rodriguez High School        3999       3999  3999  3999    3999
# Shelton High School          1761       1761  1761  1761    1761
# Thomas High School           1635       1635  1635  1635    1635
# Wilson High School           2283       2283  2283  2283    2283
# Wright High School           1800       1800  1800  1800    1800

# %%
alpha_school_data = school_data.sort_values(by="school_name", ascending="false")

# %%
schoolnames = alpha_school_data["school_name"]
alpha_school_data = alpha_school_data.set_index(schoolnames)
alpha_school_data = alpha_school_data[['type', 'size', 'budget']]

alpha_school_data

#getting this into a nice format and indexed by school name so that data pulled from it can merge with the data pulled from the grouped dataframe
# Out:
#                            type  size   budget
# school_name
# Bailey High School     District  4976  3124928
# Cabrera High School     Charter  1858  1081356
# Figueroa High School   District  2949  1884411
# Ford High School       District  2739  1763916
# Griffin High School     Charter  1468   917500
# Hernandez High School  District  4635  3022020
# Holden High School      Charter   427   248087
# Huang High School      District  2917  1910635
# Johnson High School    District  4761  3094650
# Pena High School        Charter   962   585858
# Rodriguez High School  District  3999  2547363
# Shelton High School     Charter  1761  1056600
# Thomas High School      Charter  1635  1043130
# Wilson High School      Charter  2283  1319574
# Wright High School      Charter  1800  1049400

# %%
schooltypes = alpha_school_data["type"]
budget_school=alpha_school_data["budget"]
totalstudents_school=alpha_school_data["size"]

# %%
#totalstudents_school = grouped["Student ID"].count()
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
budgetperstudent=budget_school/totalstudents_school

# %%
mathavg_school = grouped["math_score"].mean()
readingavg_school = grouped["reading_score"].mean()

# %%
passedreading_school = passedreading.groupby(["school_name"])
totalpassedreading_school = passedreading_school["Student ID"].count()
readingpasspct_school = totalpassedreading_school/totalstudents_school*100

# %%
passedmath_school = passedmath.groupby(["school_name"])
totalpassedmath_school = passedmath_school["Student ID"].count()
mathpasspct_school = totalpassedmath_school/totalstudents_school*100

# %%
passedboth_school = passedboth.groupby(["school_name"])
totalpassedboth_school = passedboth_school["Student ID"].count()
bothpasspct_school = totalpassedboth_school/totalstudents_school*100

# %%
school_summary = pd.DataFrame({"School Type":schooltypes,
                                "Number of Students": totalstudents_school,
                                "Budget": budget_school,
                               "Budget per Student": budgetperstudent,
                                "Average Math Score": mathavg_school,
                                "Average Reading Score": readingavg_school,
                                "Percent Passing Math": mathpasspct_school,
                                "Percent Passing Reading": mathpasspct_school,
                                "Percent Passing Overall": bothpasspct_school})

school_summary
# Out:
#                       School Type  Number of Students   Budget  \
# school_name
# Bailey High School       District                4976  3124928
# Cabrera High School       Charter                1858  1081356
# Figueroa High School     District                2949  1884411
# Ford High School         District                2739  1763916
# Griffin High School       Charter                1468   917500
# Hernandez High School    District                4635  3022020
# Holden High School        Charter                 427   248087
# Huang High School        District                2917  1910635
# Johnson High School      District                4761  3094650
# Pena High School          Charter                 962   585858
# Rodriguez High School    District                3999  2547363
# Shelton High School       Charter                1761  1056600
# Thomas High School        Charter                1635  1043130
# Wilson High School        Charter                2283  1319574
# Wright High School        Charter                1800  1049400
#
#                        Budget per Student  Average Math Score  \
# school_name
# Bailey High School                  628.0           77.048432
# Cabrera High School                 582.0           83.061895
# Figueroa High School                639.0           76.711767
# Ford High School                    644.0           77.102592
# Griffin High School                 625.0           83.351499
# Hernandez High School               652.0           77.289752
# Holden High School                  581.0           83.803279
# Huang High School                   655.0           76.629414
# Johnson High School                 650.0           77.072464
# Pena High School                    609.0           83.839917
# Rodriguez High School               637.0           76.842711
# Shelton High School                 600.0           83.359455
# Thomas High School                  638.0           83.418349
# Wilson High School                  578.0           83.274201
# Wright High School                  583.0           83.682222
#
#                        Average Reading Score  Percent Passing Math  \
# school_name
# Bailey High School                 81.033963             66.680064
# Cabrera High School                83.975780             94.133477
# Figueroa High School               81.158020             65.988471
# Ford High School                   80.746258             68.309602
# Griffin High School                83.816757             93.392371
# Hernandez High School              80.934412             66.752967
# Holden High School                 83.814988             92.505855
# Huang High School                  81.182722             65.683922
# Johnson High School                80.966394             66.057551
# Pena High School                   84.044699             94.594595
# Rodriguez High School              80.744686             66.366592
# Shelton High School                83.725724             93.867121
# Thomas High School                 83.848930             93.272171
# Wilson High School                 83.989488             93.867718
# Wright High School                 83.955000             93.333333
#
#                        Percent Passing Reading  Percent Passing Overall
# school_name
# Bailey High School                   66.680064                54.642283
# Cabrera High School                  94.133477                91.334769
# Figueroa High School                 65.988471                53.204476
# Ford High School                     68.309602                54.289887
# Griffin High School                  93.392371                90.599455
# Hernandez High School                66.752967                53.527508
# Holden High School                   92.505855                89.227166
# Huang High School                    65.683922                53.513884
# Johnson High School                  66.057551                53.539172
# Pena High School                     94.594595                90.540541
# Rodriguez High School                66.366592                52.988247
# Shelton High School                  93.867121                89.892107
# Thomas High School                   93.272171                90.948012
# Wilson High School                   93.867718                90.582567
# Wright High School                   93.333333                90.333333

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_schools = school_summary.sort_values(by="Percent Passing Overall", ascending=False)

top_schools.head(5)
# Out:
#                     School Type  Number of Students      Budget  \
# school_name
# Cabrera High School     Charter                1858  2009159448
# Thomas High School      Charter                1635  1705517550
# Griffin High School     Charter                1468  1346890000
# Wilson High School      Charter                2283  3012587442
# Pena High School        Charter                 962   563595396
#
#                      Budget per Student  Average Math Score  \
# school_name
# Cabrera High School           1081356.0           83.061895
# Thomas High School            1043130.0           83.418349
# Griffin High School            917500.0           83.351499
# Wilson High School            1319574.0           83.274201
# Pena High School               585858.0           83.839917
#
#                      Average Reading Score  Percent Passing Math  \
# school_name
# Cabrera High School              83.975780             94.133477
# Thomas High School               83.848930             93.272171
# Griffin High School              83.816757             93.392371
# Wilson High School               83.989488             93.867718
# Pena High School                 84.044699             94.594595
#
#                      Percent Passing Reading  Percent Passing Overall
# school_name
# Cabrera High School                94.133477                91.334769
# Thomas High School                 93.272171                90.948012
# Griffin High School                93.392371                90.599455
# Wilson High School                 93.867718                90.582567
# Pena High School                   94.594595                90.540541

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_schools = school_summary.sort_values(by="Percent Passing Overall", ascending=True)

bottom_schools.head(5)
# Out:
#                       School Type  Number of Students       Budget  \
# school_name
# Rodriguez High School    District                3999  10186904637
# Figueroa High School     District                2949   5557128039
# Huang High School        District                2917   5573322295
# Hernandez High School    District                4635  14007062700
# Johnson High School      District                4761  14733628650
#
#                        Budget per Student  Average Math Score  \
# school_name
# Rodriguez High School           2547363.0           76.842711
# Figueroa High School            1884411.0           76.711767
# Huang High School               1910635.0           76.629414
# Hernandez High School           3022020.0           77.289752
# Johnson High School             3094650.0           77.072464
#
#                        Average Reading Score  Percent Passing Math  \
# school_name
# Rodriguez High School              80.744686             66.366592
# Figueroa High School               81.158020             65.988471
# Huang High School                  81.182722             65.683922
# Hernandez High School              80.934412             66.752967
# Johnson High School                80.966394             66.057551
#
#                        Percent Passing Reading  Percent Passing Overall
# school_name
# Rodriguez High School                66.366592                52.988247
# Figueroa High School                 65.988471                53.204476
# Huang High School                    65.683922                53.513884
# Hernandez High School                66.752967                53.527508
# Johnson High School                  66.057551                53.539172

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_data_complete.dtypes
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# School ID         int64
# type             object
# size              int64
# budget            int64
# dtype: object

# %%
grade9 = school_data_complete.loc[school_data_complete["grade"] == "9th",:]
grade10 = school_data_complete.loc[school_data_complete["grade"] == "10th",:]
grade11 = school_data_complete.loc[school_data_complete["grade"] == "11th",:]
grade12 = school_data_complete.loc[school_data_complete["grade"] == "12th",:]

# %%
grouped9 = grade9.groupby(['school_name'])
grouped10 = grade10.groupby(['school_name'])
grouped11 = grade11.groupby(['school_name'])
grouped12 = grade12.groupby(['school_name'])

# %%
mathavg9 = grouped9["math_score"].mean()
mathavg10 = grouped10["math_score"].mean()
mathavg11 = grouped11["math_score"].mean()
mathavg12 = grouped12["math_score"].mean()

# %%
mathavg_grade = pd.DataFrame({"Average 9th Grade Math Score":mathavg9,
                                "Average 10th Grade Math Score":mathavg10,
                                "Average 11th Grade Math Score":mathavg11,
                                "Average 12th Grade Math Score":mathavg12})
mathavg_grade
# Out:
#                        Average 9th Grade Math Score  \
# school_name
# Bailey High School                        77.083676
# Cabrera High School                       83.094697
# Figueroa High School                      76.403037
# Ford High School                          77.361345
# Griffin High School                       82.044010
# Hernandez High School                     77.438495
# Holden High School                        83.787402
# Huang High School                         77.027251
# Johnson High School                       77.187857
# Pena High School                          83.625455
# Rodriguez High School                     76.859966
# Shelton High School                       83.420755
# Thomas High School                        83.590022
# Wilson High School                        83.085578
# Wright High School                        83.264706
#
#                        Average 10th Grade Math Score  \
# school_name
# Bailey High School                         76.996772
# Cabrera High School                        83.154506
# Figueroa High School                       76.539974
# Ford High School                           77.672316
# Griffin High School                        84.229064
# Hernandez High School                      77.337408
# Holden High School                         83.429825
# Huang High School                          75.908735
# Johnson High School                        76.691117
# Pena High School                           83.372000
# Rodriguez High School                      76.612500
# Shelton High School                        82.917411
# Thomas High School                         83.087886
# Wilson High School                         83.724422
# Wright High School                         84.010288
#
#                        Average 11th Grade Math Score  \
# school_name
# Bailey High School                         77.515588
# Cabrera High School                        82.765560
# Figueroa High School                       76.884344
# Ford High School                           76.918058
# Griffin High School                        83.842105
# Hernandez High School                      77.136029
# Holden High School                         85.000000
# Huang High School                          76.446602
# Johnson High School                        77.491653
# Pena High School                           84.328125
# Rodriguez High School                      76.395626
# Shelton High School                        83.383495
# Thomas High School                         83.498795
# Wilson High School                         83.195326
# Wright High School                         83.836782
#
#                        Average 12th Grade Math Score
# school_name
# Bailey High School                         76.492218
# Cabrera High School                        83.277487
# Figueroa High School                       77.151369
# Ford High School                           76.179963
# Griffin High School                        83.356164
# Hernandez High School                      77.186567
# Holden High School                         82.855422
# Huang High School                          77.225641
# Johnson High School                        76.863248
# Pena High School                           84.121547
# Rodriguez High School                      77.690748
# Shelton High School                        83.778976
# Thomas High School                         83.497041
# Wilson High School                         83.035794
# Wright High School                         83.644986

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
readingavg9 = grouped9['reading_score'].mean()
readingavg10 = grouped10['reading_score'].mean()
readingavg11 = grouped11['reading_score'].mean()
readingavg12 = grouped12['reading_score'].mean()

# %%
readingavg_grade = pd.DataFrame({"Average 9th Grade Reading Score":readingavg9,
                                "Average 10th Grade Reading Score":readingavg10,
                                "Average 11th Grade Reading Score":readingavg11,
                                "Average 12th Grade Reading Score":readingavg12})
readingavg_grade
# Out:
#                        Average 9th Grade Reading Score  \
# school_name
# Bailey High School                           81.303155
# Cabrera High School                          83.676136
# Figueroa High School                         81.198598
# Ford High School                             80.632653
# Griffin High School                          83.369193
# Hernandez High School                        80.866860
# Holden High School                           83.677165
# Huang High School                            81.290284
# Johnson High School                          81.260714
# Pena High School                             83.807273
# Rodriguez High School                        80.993127
# Shelton High School                          84.122642
# Thomas High School                           83.728850
# Wilson High School                           83.939778
# Wright High School                           83.833333
#
#                        Average 10th Grade Reading Score  \
# school_name
# Bailey High School                            80.907183
# Cabrera High School                           84.253219
# Figueroa High School                          81.408912
# Ford High School                              81.262712
# Griffin High School                           83.706897
# Hernandez High School                         80.660147
# Holden High School                            83.324561
# Huang High School                             81.512386
# Johnson High School                           80.773431
# Pena High School                              83.612000
# Rodriguez High School                         80.629808
# Shelton High School                           83.441964
# Thomas High School                            84.254157
# Wilson High School                            84.021452
# Wright High School                            83.812757
#
#                        Average 11th Grade Reading Score  \
# school_name
# Bailey High School                            80.945643
# Cabrera High School                           83.788382
# Figueroa High School                          80.640339
# Ford High School                              80.403642
# Griffin High School                           84.288089
# Hernandez High School                         81.396140
# Holden High School                            83.815534
# Huang High School                             81.417476
# Johnson High School                           80.616027
# Pena High School                              84.335938
# Rodriguez High School                         80.864811
# Shelton High School                           84.373786
# Thomas High School                            83.585542
# Wilson High School                            83.764608
# Wright High School                            84.156322
#
#                        Average 12th Grade Reading Score
# school_name
# Bailey High School                            80.912451
# Cabrera High School                           84.287958
# Figueroa High School                          81.384863
# Ford High School                              80.662338
# Griffin High School                           84.013699
# Hernandez High School                         80.857143
# Holden High School                            84.698795
# Huang High School                             80.305983
# Johnson High School                           81.227564
# Pena High School                              84.591160
# Rodriguez High School                         80.376426
# Shelton High School                           82.781671
# Thomas High School                            83.831361
# Wilson High School                            84.317673
# Wright High School                            84.073171

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
spending  = alpha_school_data
#starting in a new dataframe so i don't mess up the one that's working!
spending.head()
# Out:
#                           type  size   budget  Budget per Student
# school_name
# Bailey High School    District  4976  3124928               628.0
# Cabrera High School    Charter  1858  1081356               582.0
# Figueroa High School  District  2949  1884411               639.0
# Ford High School      District  2739  1763916               644.0
# Griffin High School    Charter  1468   917500               625.0

# %%
#spending = school_data_complete[['school_name','reading_score', 'math_score','size', 'budget']]

# %%
spending["Budget per Student"] = spending["budget"]/spending["size"]
spending.head()
# Out:
#                           type  size   budget  Budget per Student
# school_name
# Bailey High School    District  4976  3124928               628.0
# Cabrera High School    Charter  1858  1081356               582.0
# Figueroa High School  District  2949  1884411               639.0
# Ford High School      District  2739  1763916               644.0
# Griffin High School    Charter  1468   917500               625.0

# %%
school_summary.columns
# Out:
# Index(['School Type', 'Number of Students', 'Budget', 'Budget per Student',
#        'Average Math Score', 'Average Reading Score', 'Percent Passing Math',
#        'Percent Passing Reading', 'Percent Passing Overall'],
#       dtype='object')

# %%
addcolumns = school_summary[['Average Math Score', 'Average Reading Score', 'Percent Passing Math',
       'Percent Passing Reading', 'Percent Passing Overall']]

# %%
school_aspects = pd.merge(spending, addcolumns, left_index=True, right_index=True)
#looked at https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html for merging on indexes
school_aspects
# Out:
#                            type  size   budget  Budget per Student        Bin  \
# school_name
# Bailey High School     District  4976  3124928               628.0  625 - 649
# Cabrera High School     Charter  1858  1081356               582.0  575 - 599
# Figueroa High School   District  2949  1884411               639.0  625 - 649
# Ford High School       District  2739  1763916               644.0  625 - 649
# Griffin High School     Charter  1468   917500               625.0  625 - 649
# Hernandez High School  District  4635  3022020               652.0  650 - 675
# Holden High School      Charter   427   248087               581.0  575 - 599
# Huang High School      District  2917  1910635               655.0  650 - 675
# Johnson High School    District  4761  3094650               650.0  650 - 675
# Pena High School        Charter   962   585858               609.0  600 - 624
# Rodriguez High School  District  3999  2547363               637.0  625 - 649
# Shelton High School     Charter  1761  1056600               600.0  600 - 624
# Thomas High School      Charter  1635  1043130               638.0  625 - 649
# Wilson High School      Charter  2283  1319574               578.0  575 - 599
# Wright High School      Charter  1800  1049400               583.0  575 - 599
#
#                        Average Math Score  Average Reading Score  \
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# Wilson High School              83.274201              83.989488
# Wright High School              83.682222              83.955000
#
#                        Percent Passing Math  Percent Passing Reading  \
# school_name
# Bailey High School                66.680064                66.680064
# Cabrera High School               94.133477                94.133477
# Figueroa High School              65.988471                65.988471
# Ford High School                  68.309602                68.309602
# Griffin High School               93.392371                93.392371
# Hernandez High School             66.752967                66.752967
# Holden High School                92.505855                92.505855
# Huang High School                 65.683922                65.683922
# Johnson High School               66.057551                66.057551
# Pena High School                  94.594595                94.594595
# Rodriguez High School             66.366592                66.366592
# Shelton High School               93.867121                93.867121
# Thomas High School                93.272171                93.272171
# Wilson High School                93.867718                93.867718
# Wright High School                93.333333                93.333333
#
#                        Percent Passing Overall
# school_name
# Bailey High School                   54.642283
# Cabrera High School                  91.334769
# Figueroa High School                 53.204476
# Ford High School                     54.289887
# Griffin High School                  90.599455
# Hernandez High School                53.527508
# Holden High School                   89.227166
# Huang High School                    53.513884
# Johnson High School                  53.539172
# Pena High School                     90.540541
# Rodriguez High School                52.988247
# Shelton High School                  89.892107
# Thomas High School                   90.948012
# Wilson High School                   90.582567
# Wright High School                   90.333333

# %%
school_aspects["Budget per Student"].sort_values()
# Out:
# school_name
# Wilson High School       578.0
# Holden High School       581.0
# Cabrera High School      582.0
# Wright High School       583.0
# Shelton High School      600.0
# Pena High School         609.0
# Griffin High School      625.0
# Bailey High School       628.0
# Rodriguez High School    637.0
# Thomas High School       638.0
# Figueroa High School     639.0
# Ford High School         644.0
# Johnson High School      650.0
# Hernandez High School    652.0
# Huang High School        655.0
# Name: Budget per Student, dtype: float64

# %%
bins = [575,600,625,650,675]
groupnames = ["575 - 599","600 - 624","625 - 649","650 - 675"]

# %%
school_aspects["Budget Range (Dollars Per Student)"] = pd.cut(school_aspects["Budget per Student"], bins, labels = groupnames)

# %%
school_aspects
# Out:
#                            type  size   budget  Budget per Student        Bin  \
# school_name
# Bailey High School     District  4976  3124928               628.0  625 - 649
# Cabrera High School     Charter  1858  1081356               582.0  575 - 599
# Figueroa High School   District  2949  1884411               639.0  625 - 649
# Ford High School       District  2739  1763916               644.0  625 - 649
# Griffin High School     Charter  1468   917500               625.0  625 - 649
# Hernandez High School  District  4635  3022020               652.0  650 - 675
# Holden High School      Charter   427   248087               581.0  575 - 599
# Huang High School      District  2917  1910635               655.0  650 - 675
# Johnson High School    District  4761  3094650               650.0  650 - 675
# Pena High School        Charter   962   585858               609.0  600 - 624
# Rodriguez High School  District  3999  2547363               637.0  625 - 649
# Shelton High School     Charter  1761  1056600               600.0  600 - 624
# Thomas High School      Charter  1635  1043130               638.0  625 - 649
# Wilson High School      Charter  2283  1319574               578.0  575 - 599
# Wright High School      Charter  1800  1049400               583.0  575 - 599
#
#                        Average Math Score  Average Reading Score  \
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# Wilson High School              83.274201              83.989488
# Wright High School              83.682222              83.955000
#
#                        Percent Passing Math  Percent Passing Reading  \
# school_name
# Bailey High School                66.680064                66.680064
# Cabrera High School               94.133477                94.133477
# Figueroa High School              65.988471                65.988471
# Ford High School                  68.309602                68.309602
# Griffin High School               93.392371                93.392371
# Hernandez High School             66.752967                66.752967
# Holden High School                92.505855                92.505855
# Huang High School                 65.683922                65.683922
# Johnson High School               66.057551                66.057551
# Pena High School                  94.594595                94.594595
# Rodriguez High School             66.366592                66.366592
# Shelton High School               93.867121                93.867121
# Thomas High School                93.272171                93.272171
# Wilson High School                93.867718                93.867718
# Wright High School                93.333333                93.333333
#
#                        Percent Passing Overall  \
# school_name
# Bailey High School                   54.642283
# Cabrera High School                  91.334769
# Figueroa High School                 53.204476
# Ford High School                     54.289887
# Griffin High School                  90.599455
# Hernandez High School                53.527508
# Holden High School                   89.227166
# Huang High School                    53.513884
# Johnson High School                  53.539172
# Pena High School                     90.540541
# Rodriguez High School                52.988247
# Shelton High School                  89.892107
# Thomas High School                   90.948012
# Wilson High School                   90.582567
# Wright High School                   90.333333
#
#                       Budget Range (Dollars Per Student)
# school_name
# Bailey High School                             625 - 649
# Cabrera High School                            575 - 599
# Figueroa High School                           625 - 649
# Ford High School                               625 - 649
# Griffin High School                            600 - 624
# Hernandez High School                          650 - 675
# Holden High School                             575 - 599
# Huang High School                              650 - 675
# Johnson High School                            625 - 649
# Pena High School                               600 - 624
# Rodriguez High School                          625 - 649
# Shelton High School                            575 - 599
# Thomas High School                             625 - 649
# Wilson High School                             575 - 599
# Wright High School                             575 - 599

# %%
len(school_aspects["Budget per Student"])
#Getting this for the list comprehension below, although looking at it i already had it because it's just the total number of students!
# Out:
# 15

# %%
len(range(0,16))
# Out:
# 16

# %%
for x in schoolnames:
    if school_aspects.loc[x, "Budget per Student"] < 600:
        school_aspects.loc[x,"Budget Range (Dollars Per Student)"] = "575 - 599"
    elif school_aspects.loc[x, "Budget per Student"] < 625:
        school_aspects.loc[x,"Budget Range (Dollars Per Student)"] = "600 - 624"   
    elif school_aspects.loc[x, "Budget per Student"] < 650:
        school_aspects.loc[x,"Budget Range (Dollars Per Student)"] = "625 - 649"   
    else:
        school_aspects.loc[x,"Budget Range (Dollars Per Student)"] = "650 - 675"



school_aspects
# Out:
#                            type  size   budget  Budget per Student  \
# school_name
# Bailey High School     District  4976  3124928               628.0
# Cabrera High School     Charter  1858  1081356               582.0
# Figueroa High School   District  2949  1884411               639.0
# Ford High School       District  2739  1763916               644.0
# Griffin High School     Charter  1468   917500               625.0
# Hernandez High School  District  4635  3022020               652.0
# Holden High School      Charter   427   248087               581.0
# Huang High School      District  2917  1910635               655.0
# Johnson High School    District  4761  3094650               650.0
# Pena High School        Charter   962   585858               609.0
# Rodriguez High School  District  3999  2547363               637.0
# Shelton High School     Charter  1761  1056600               600.0
# Thomas High School      Charter  1635  1043130               638.0
# Wilson High School      Charter  2283  1319574               578.0
# Wright High School      Charter  1800  1049400               583.0
#
#                        Average Math Score  Average Reading Score  \
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# Wilson High School              83.274201              83.989488
# Wright High School              83.682222              83.955000
#
#                        Percent Passing Math  Percent Passing Reading  \
# school_name
# Bailey High School                66.680064                66.680064
# Cabrera High School               94.133477                94.133477
# Figueroa High School              65.988471                65.988471
# Ford High School                  68.309602                68.309602
# Griffin High School               93.392371                93.392371
# Hernandez High School             66.752967                66.752967
# Holden High School                92.505855                92.505855
# Huang High School                 65.683922                65.683922
# Johnson High School               66.057551                66.057551
# Pena High School                  94.594595                94.594595
# Rodriguez High School             66.366592                66.366592
# Shelton High School               93.867121                93.867121
# Thomas High School                93.272171                93.272171
# Wilson High School                93.867718                93.867718
# Wright High School                93.333333                93.333333
#
#                        Percent Passing Overall  \
# school_name
# Bailey High School                   54.642283
# Cabrera High School                  91.334769
# Figueroa High School                 53.204476
# Ford High School                     54.289887
# Griffin High School                  90.599455
# Hernandez High School                53.527508
# Holden High School                   89.227166
# Huang High School                    53.513884
# Johnson High School                  53.539172
# Pena High School                     90.540541
# Rodriguez High School                52.988247
# Shelton High School                  89.892107
# Thomas High School                   90.948012
# Wilson High School                   90.582567
# Wright High School                   90.333333
#
#                       Budget Range (Dollars Per Student)
# school_name
# Bailey High School                             625 - 649
# Cabrera High School                            575 - 599
# Figueroa High School                           625 - 649
# Ford High School                               625 - 649
# Griffin High School                            625 - 649
# Hernandez High School                          650 - 675
# Holden High School                             575 - 599
# Huang High School                              650 - 675
# Johnson High School                            650 - 675
# Pena High School                               600 - 624
# Rodriguez High School                          625 - 649
# Shelton High School                            600 - 624
# Thomas High School                             625 - 649
# Wilson High School                             575 - 599
# Wright High School                             575 - 599

# %%
spending_summary = School.groupby("Bin")
spending_summary.count()
# Out:
#      School Name  Budget per Student  Average Math Score  \
# Bin
# 1.0            2                   2                   2
# 2.0            5                   5                   5
# 3.0            4                   4                   4
# 4.0            4                   4                   4
#
#      Average Reading Score  Percent Passing Math  Percent Passing Reading  \
# Bin
# 1.0                      2                     2                        2
# 2.0                      5                     5                        5
# 3.0                      4                     4                        4
# 4.0                      4                     4                        4
#
#      Percent Passing Overall  Spending Range ($ Per Student)
# Bin
# 1.0                        2                               2
# 2.0                        5                               5
# 3.0                        4                               4
# 4.0                        4                               4

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
